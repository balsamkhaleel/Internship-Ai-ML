# %% [markdown]
# # فحص إعداد البيئة
#    هذا الـ notebook يتأكد من تثبيت numpy, pandas, matplotlib بنجاح.

# %%
import numpy
import pandas
import matplotlib

print("numpy:", numpy.__version__)
print("pandas:", pandas.__version__)
print("matplotlib:", matplotlib.__version__)
# Out:
# numpy: 2.3.5
# pandas: 2.3.3
# matplotlib: 3.10.6
