# %% [markdown]
# # Environment Setup Check
# This notebook verifies that numpy, pandas, and matplotlib are installed correctly.

# %%
import numpy
import pandas
import matplotlib

print("numpy:", numpy.__version__)
print("pandas:", pandas.__version__)
print("matplotlib:", matplotlib.__version__)

# %% [markdown]
# ## Summary
# The virtual environment is set up correctly, and all core libraries (numpy, pandas, matplotlib) are installed and working.
